# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://docs.deepnote.com/environment/custom-initialization).

# %%
# %%bash
# if test -f ~/work/requirements.txt
#   then
#     sed -i '/jupyter/d' ~/work/requirements.txt
#     pip install -r ~/work/requirements.txt
#   else echo "Found no requirements.txt"
# fi
# Out:
# Obtaining file:///home/jovyan/work (from -r /home/jovyan/work/requirements.txt (line 2))
# Collecting dvc[gdrive]
#   Downloading dvc-1.8.1-py2.py3-none-any.whl (481 kB)
# Collecting tqdm
#   Downloading tqdm-4.50.0-py2.py3-none-any.whl (70 kB)
# Requirement already satisfied: numpy in /opt/venv/lib/python3.7/site-packages (from -r /home/jovyan/work/requirements.txt (line 5)) (1.19.2)
# Requirement already satisfied: scipy in /opt/venv/lib/python3.7/site-packages (from -r /home/jovyan/work/requirements.txt (line 6)) (1.5.2)
# Requirement already satisfied: ipywidgets in /opt/venv/lib/python3.7/site-packages (from -r /home/jovyan/work/requirements.txt (line 7)) (7.5.1)
# Collecting dask[delayed,distributed]
#   Downloading dask-2.29.0-py3-none-any.whl (847 kB)
# Collecting shtab<2,>=1.3.2
#   Downloading shtab-1.3.2-py2.py3-none-any.whl (12 kB)
# Collecting gitpython>3
#   Downloading GitPython-3.1.9-py3-none-any.whl (159 kB)
# Collecting flufl.lock<4,>=3.2
#   Downloading flufl.lock-3.2.tar.gz (19 kB)
# Requirement already satisfied: requests>=2.22.0 in /opt/venv/lib/python3.7/site-packages (from dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (2.24.0)
# Collecting distro>=1.3.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting dpath<3,>=2.0.1
#   Downloading dpath-2.0.1.tar.gz (21 kB)
# Collecting ply>=3.9
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
# Requirement already satisfied: packaging>=19.0 in /opt/venv/lib/python3.7/site-packages (from dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (20.4)
# Collecting dictdiffer>=0.8.1
#   Downloading dictdiffer-0.8.1-py2.py3-none-any.whl (16 kB)
# Collecting configobj>=5.0.6
#   Downloading configobj-5.0.6.tar.gz (33 kB)
# Collecting grandalf==0.6
#   Downloading grandalf-0.6-py3-none-any.whl (31 kB)
# Collecting zc.lockfile>=1.2.1
#   Downloading zc.lockfile-2.0-py2.py3-none-any.whl (9.7 kB)
# Collecting pydot>=1.2.4
#   Downloading pydot-1.4.1-py2.py3-none-any.whl (19 kB)
# Collecting pathspec>=0.6.0
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting tabulate>=0.8.7
#   Downloading tabulate-0.8.7-py3-none-any.whl (24 kB)
# Collecting nanotime>=0.5.2
#   Downloading nanotime-0.5.2.tar.gz (3.2 kB)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.1-py3-none-any.whl (7.5 kB)
# Collecting ruamel.yaml>=0.16.1
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting flatten-dict<1,>=0.3.0
#   Downloading flatten_dict-0.3.0-py2.py3-none-any.whl (8.2 kB)
# Collecting colorama>=0.3.9
#   Downloading colorama-0.4.3-py2.py3-none-any.whl (15 kB)
# Collecting voluptuous>=0.11.7
#   Downloading voluptuous-0.12.0-py3-none-any.whl (29 kB)
# Collecting jsonpath-ng>=1.5.1
#   Downloading jsonpath_ng-1.5.2-py3-none-any.whl (28 kB)
# Collecting appdirs>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting toml>=0.10.1
#   Downloading toml-0.10.1-py2.py3-none-any.whl (19 kB)
# Collecting funcy>=1.14
#   Downloading funcy-1.15-py2.py3-none-any.whl (32 kB)
# Collecting networkx<2.5,>=2.1
#   Downloading networkx-2.4-py3-none-any.whl (1.6 MB)
# Requirement already satisfied: setuptools>=34.0.0 in /opt/venv/lib/python3.7/site-packages (from dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (49.6.0)
# Collecting rich>=3.0.5
#   Downloading rich-7.1.0-py3-none-any.whl (153 kB)
# Collecting pygtrie==2.3.2
#   Downloading pygtrie-2.3.2.tar.gz (33 kB)
# Collecting pyasn1>=0.4.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting pydrive2>=1.6.2; extra == "gdrive"
#   Downloading PyDrive2-1.6.2-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: six>=1.13.0; extra == "gdrive" in /opt/venv/lib/python3.7/site-packages (from dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (1.15.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/venv/lib/python3.7/site-packages (from ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (5.3.4)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /opt/venv/lib/python3.7/site-packages (from ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (7.18.1)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/venv/lib/python3.7/site-packages (from ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (5.0.4)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/venv/lib/python3.7/site-packages (from ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (3.5.1)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/venv/lib/python3.7/site-packages (from ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (5.0.7)
# Collecting pyyaml
#   Downloading PyYAML-5.3.1.tar.gz (269 kB)
# Collecting toolz>=0.8.2; extra == "delayed"
#   Downloading toolz-0.11.1-py3-none-any.whl (55 kB)
# Collecting cloudpickle>=0.2.2; extra == "delayed"
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting distributed>=2.0; extra == "distributed"
#   Downloading distributed-2.29.0-py3-none-any.whl (653 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.5-py3-none-any.whl (63 kB)
# Collecting atpublic
#   Downloading atpublic-2.0.tar.gz (14 kB)
# Requirement already satisfied: idna<3,>=2.5 in /opt/venv/lib/python3.7/site-packages (from requests>=2.22.0->dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/venv/lib/python3.7/site-packages (from requests>=2.22.0->dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/venv/lib/python3.7/site-packages (from requests>=2.22.0->dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/venv/lib/python3.7/site-packages (from requests>=2.22.0->dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (1.25.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/venv/lib/python3.7/site-packages (from packaging>=19.0->dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (2.4.7)
# Collecting future
#   Downloading future-0.18.2.tar.gz (829 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp37-cp37m-manylinux1_x86_64.whl (547 kB)
# Collecting pathlib2<3.0,>=2.3
#   Downloading pathlib2-2.3.5-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: decorator in /opt/venv/lib/python3.7/site-packages (from jsonpath-ng>=1.5.1->dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (4.4.2)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/venv/lib/python3.7/site-packages (from rich>=3.0.5->dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (2.7.0)
# Collecting typing-extensions<4.0.0,>=3.7.4
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting oauth2client>=4.0.0
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
# Collecting pyOpenSSL>=19.1.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting google-api-python-client>=1.12.1
#   Downloading google_api_python_client-1.12.3-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied: tornado>=4.2 in /opt/venv/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (6.0.4)
# Requirement already satisfied: jupyter-client in /opt/venv/lib/python3.7/site-packages (from ipykernel>=4.5.1->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (6.1.7)
# Requirement already satisfied: backcall in /opt/venv/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/venv/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.7.5)
# Requirement already satisfied: jedi>=0.10 in /opt/venv/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.17.2)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /opt/venv/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/venv/lib/python3.7/site-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (3.0.7)
# Requirement already satisfied: ipython-genutils in /opt/venv/lib/python3.7/site-packages (from traitlets>=4.3.1->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /opt/venv/lib/python3.7/site-packages (from widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (7.0.0.dev0)
# Requirement already satisfied: jupyter-core in /opt/venv/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (4.6.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/venv/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (3.2.0)
# Collecting sortedcontainers!=2.0.0,!=2.0.1
#   Downloading sortedcontainers-2.2.2-py2.py3-none-any.whl (29 kB)
# Collecting click>=6.6
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting tblib>=1.6.0
#   Downloading tblib-1.7.0-py2.py3-none-any.whl (12 kB)
# Collecting msgpack>=0.6.0
#   Downloading msgpack-1.0.0-cp37-cp37m-manylinux1_x86_64.whl (275 kB)
# Collecting zict>=0.1.3
#   Downloading zict-2.0.0-py3-none-any.whl (10 kB)
# Collecting psutil>=5.0
#   Downloading psutil-5.7.2.tar.gz (460 kB)
# Collecting smmap<4,>=3.0.1
#   Downloading smmap-3.0.4-py2.py3-none-any.whl (25 kB)
# Collecting rsa>=3.1.4
#   Downloading rsa-4.6-py3-none-any.whl (47 kB)
# Collecting pyasn1-modules>=0.0.5
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Collecting httplib2>=0.9.1
#   Downloading httplib2-0.18.1-py3-none-any.whl (95 kB)
# Collecting cryptography>=2.8
#   Downloading cryptography-3.1.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting uritemplate<4dev,>=3.0.0
#   Downloading uritemplate-3.0.1-py2.py3-none-any.whl (15 kB)
# Collecting google-auth-httplib2>=0.0.3
#   Downloading google_auth_httplib2-0.0.4-py2.py3-none-any.whl (9.1 kB)
# Collecting google-auth>=1.16.0
#   Downloading google_auth-1.22.0-py2.py3-none-any.whl (114 kB)
# Collecting google-api-core<2dev,>=1.21.0
#   Downloading google_api_core-1.22.3-py2.py3-none-any.whl (91 kB)
# Requirement already satisfied: pyzmq>=13 in /opt/venv/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (19.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in /opt/venv/lib/python3.7/site-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (2.8.1)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /opt/venv/lib/python3.7/site-packages (from jedi>=0.10->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/venv/lib/python3.7/site-packages (from pexpect>4.3; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: wcwidth in /opt/venv/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0; python_version >= "3.3"->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.2.5)
# Requirement already satisfied: prometheus-client in /opt/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.8.0)
# Requirement already satisfied: terminado>=0.8.1 in /opt/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.8.3)
# Requirement already satisfied: Send2Trash in /opt/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: jinja2 in /opt/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (2.11.2)
# Requirement already satisfied: nbconvert in /opt/venv/lib/python3.7/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (6.0.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/venv/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (1.7.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/venv/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (20.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/venv/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.17.3)
# Collecting heapdict
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.3-cp37-cp37m-manylinux1_x86_64.whl (401 kB)
# Collecting cachetools<5.0,>=2.0.0
#   Downloading cachetools-4.1.1-py3-none-any.whl (10 kB)
# Collecting aiohttp<4.0.0dev,>=3.6.2; python_version >= "3.6"
#   Downloading aiohttp-3.6.2-cp37-cp37m-manylinux1_x86_64.whl (1.2 MB)
# Requirement already satisfied: pytz in /opt/venv/lib/python3.7/site-packages (from google-api-core<2dev,>=1.21.0->google-api-python-client>=1.12.1->pydrive2>=1.6.2; extra == "gdrive"->dvc[gdrive]->-r /home/jovyan/work/requirements.txt (line 3)) (2020.1)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.13.0-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Collecting googleapis-common-protos<2.0dev,>=1.6.0
#   Downloading googleapis_common_protos-1.52.0-py2.py3-none-any.whl (100 kB)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/venv/lib/python3.7/site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: defusedxml in /opt/venv/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/venv/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/venv/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/venv/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/venv/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.5.0)
# Requirement already satisfied: testpath in /opt/venv/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/venv/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: bleach in /opt/venv/lib/python3.7/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (3.1.5)
# Requirement already satisfied: zipp>=0.5 in /opt/venv/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (3.1.0)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Collecting multidict<5.0,>=4.5
#   Downloading multidict-4.7.6-cp37-cp37m-manylinux1_x86_64.whl (149 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.0-cp37-cp37m-manylinux1_x86_64.whl (258 kB)
# Requirement already satisfied: async-generator in /opt/venv/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (1.10)
# Requirement already satisfied: nest-asyncio in /opt/venv/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (1.4.0)
# Requirement already satisfied: webencodings in /opt/venv/lib/python3.7/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets->-r /home/jovyan/work/requirements.txt (line 7)) (0.5.1)
# Building wheels for collected packages: flufl.lock, dpath, configobj, nanotime, pygtrie, pyyaml, atpublic, future, psutil
#   Building wheel for flufl.lock (setup.py): started
#   Building wheel for flufl.lock (setup.py): finished with status 'done'
#   Created wheel for flufl.lock: filename=flufl.lock-3.2-py3-none-any.whl size=19929 sha256=37d108a30382039d4a3214d33e4afd44cf29cff034f01e213ff1e0e539351b49
#   Stored in directory: /home/jovyan/.cache/pip/wheels/49/68/a0/8e7cb7bbf4990fc10b5a082aa0eb3ac66787ca11e8eca445b2
#   Building wheel for dpath (setup.py): started
#   Building wheel for dpath (setup.py): finished with status 'done'
#   Created wheel for dpath: filename=dpath-2.0.1-py3-none-any.whl size=15139 sha256=694e2da3ebc3dab9e19bf8866a6382195979e9f6b807fa3c0f57108395fe1d25
#   Stored in directory: /home/jovyan/.cache/pip/wheels/bc/f8/ae/bc69cb5f61393ebf9ade4cde41d1a813d35bfe78263a26f99e
#   Building wheel for configobj (setup.py): started
#   Building wheel for configobj (setup.py): finished with status 'done'
#   Created wheel for configobj: filename=configobj-5.0.6-py3-none-any.whl size=34545 sha256=0fb8f70969b4fce215a81ae5dcedab92262c6b5ce1d5deb4af7ce73917b4c3e0
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0d/c4/19/13d74440f2a571841db6b6e0a273694327498884dafb9cf978
#   Building wheel for nanotime (setup.py): started
#   Building wheel for nanotime (setup.py): finished with status 'done'
#   Created wheel for nanotime: filename=nanotime-0.5.2-py3-none-any.whl size=2442 sha256=ea41ef1d1c07cc5ab59828d88b91ba27c4467808b94be99b590b9b713de4be96
#   Stored in directory: /home/jovyan/.cache/pip/wheels/b8/92/aa/456d462c908b4e210c3928f778d28f94049fc9e47af8b191c9
#   Building wheel for pygtrie (setup.py): started
#   Building wheel for pygtrie (setup.py): finished with status 'done'
#   Created wheel for pygtrie: filename=pygtrie-2.3.2-py3-none-any.whl size=18866 sha256=299beee868066007a2d4d986509c7dddca129e3a5f111707915c2a0992672e0c
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ce/22/5c/bcd55db68399954d13c8d3b23192a517dd59ba3ee8648fa773
#   Building wheel for pyyaml (setup.py): started
#   Building wheel for pyyaml (setup.py): finished with status 'done'
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44619 sha256=af77ec6ed7537463ffb691d09e780933f2f6a12bb2b9d4a2978729dcc4675d83
#   Stored in directory: /home/jovyan/.cache/pip/wheels/5e/03/1e/e1e954795d6f35dfc7b637fe2277bff021303bd9570ecea653
#   Building wheel for atpublic (setup.py): started
#   Building wheel for atpublic (setup.py): finished with status 'done'
#   Created wheel for atpublic: filename=atpublic-2.0-py3-none-any.whl size=14698 sha256=2c51005bfaae865dc42cdb2f04b39fa076f8e65a3390b094744bc76243bbcc24
#   Stored in directory: /home/jovyan/.cache/pip/wheels/3e/5d/46/fa3cbde0ab8c53dbdd14658b3a4c97035b8851369ce8e79649
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491059 sha256=1c785250515c91ab45cf9058ca3b04f0e3d8252bdc20845006bf2c60c2a2e3a4
#   Stored in directory: /home/jovyan/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for psutil (setup.py): started
#   Building wheel for psutil (setup.py): finished with status 'done'
#   Created wheel for psutil: filename=psutil-5.7.2-cp37-cp37m-linux_x86_64.whl size=282605 sha256=698c5a53bd4d4a69926728333b181e6032d46440490a99f94d6e33f902ad2b27
#   Stored in directory: /home/jovyan/.cache/pip/wheels/2d/43/97/00701864a7bee6d9e1a52dd682537dcbf1d013d0e2e6f0c1f1
# Successfully built flufl.lock dpath configobj nanotime pygtrie pyyaml atpublic future psutil
# Installing collected packages: shtab, smmap, gitdb, gitpython, tqdm, typing-extensions, atpublic, flufl.lock, distro, dpath, ply, dictdiffer, configobj, future, grandalf, zc.lockfile, pydot, pathspec, tabulate, nanotime, shortuuid, ruamel.yaml.clib, ruamel.yaml, pathlib2, flatten-dict, colorama, voluptuous, jsonpath-ng, appdirs, toml, funcy, networkx, commonmark, rich, pygtrie, pyasn1, rsa, pyasn1-modules, httplib2, oauth2client, pycparser, cffi, cryptography, pyOpenSSL, uritemplate, cachetools, async-timeout, multidict, yarl, aiohttp, google-auth, google-auth-httplib2, protobuf, googleapis-common-protos, google-api-core, google-api-python-client, pyyaml, pydrive2, dvc, toolz, cloudpickle, sortedcontainers, click, tblib, msgpack, heapdict, zict, psutil, distributed, dask, MCMC-Norm-Learning
#   Running setup.py develop for MCMC-Norm-Learning
# Successfully installed MCMC-Norm-Learning aiohttp-3.6.2 appdirs-1.4.4 async-timeout-3.0.1 atpublic-2.0 cachetools-4.1.1 cffi-1.14.3 click-7.1.2 cloudpickle-1.6.0 colorama-0.4.3 commonmark-0.9.1 configobj-5.0.6 cryptography-3.1.1 dask-2.29.0 dictdiffer-0.8.1 distributed-2.29.0 distro-1.5.0 dpath-2.0.1 dvc-1.8.1 flatten-dict-0.3.0 flufl.lock-3.2 funcy-1.15 future-0.18.2 gitdb-4.0.5 gitpython-3.1.9 google-api-core-1.22.3 google-api-python-client-1.12.3 google-auth-1.22.0 google-auth-httplib2-0.0.4 googleapis-common-protos-1.52.0 grandalf-0.6 heapdict-1.0.1 httplib2-0.18.1 jsonpath-ng-1.5.2 msgpack-1.0.0 multidict-4.7.6 nanotime-0.5.2 networkx-2.4 oauth2client-4.1.3 pathlib2-2.3.5 pathspec-0.8.0 ply-3.11 protobuf-3.13.0 psutil-5.7.2 pyOpenSSL-19.1.0 pyasn1-0.4.8 pyasn1-modules-0.2.8 pycparser-2.20 pydot-1.4.1 pydrive2-1.6.2 pygtrie-2.3.2 pyyaml-5.3.1 rich-7.1.0 rsa-4.6 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 shortuuid-1.0.1 shtab-1.3.2 smmap-3.0.4 sortedcontainers-2.2.2 tabulate-0.8.7 tblib-1.7.0 toml-0.10.1 toolz-0.11.1 tqdm-4.50.0 typing-extensions-3.7.4.3 uritemplate-3.0.1 voluptuous-0.12.0 yarl-1.6.0 zc.lockfile-2.0 zict-2.0.0
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
# %%bash
# # If you have previously installed any packages into this project, we re-install them here to restore your environment.
# #if test -f .deepnote/requirements.txt
# #  then
# #    sed -i '/jupyter/d' .deepnote/requirements.txt
# #    pip install -r .deepnote/requirements.txt
# #  else echo "Seems like there is nothing to restore. Most likely, you haven't installed any extra packages so far."
# #fi
